# %% [markdown]
# First we will load files from our content based and collaborative models. Then we will define our hybrid functions.

# %%
from scipy.sparse import load_npz
import joblib
import pandas as pd
import numpy as np

# %%
# Load saved files from content based model
tfidf_matrix = load_npz("data/tfidf_matrix.npz")
cosine_sim = joblib.load("data/cosine_sim.pkl")
anime_filtered_df = pd.read_csv("data/anime_filtered_processed.csv")
tfidf_vectorizer = joblib.load("data/tfidf_vectorizer.pkl")
final_features = load_npz("data/final_features.npz")

# %%
anime_filtered_df.head()
# Out:
#    anime_id                             name  score    rank  \
# 0         1                     cowboy bebop   8.75    41.0
# 1         5  cowboy bebop: tengoku no tobira   8.38   189.0
# 2         6                           trigun   8.22   328.0
# 3         7               witch hunter robin   7.25  2764.0
# 4         8                   bouken ou beet   6.94  4240.0
#
#                                  genres  \
# 0         action, award winning, sci-fi
# 1                        action, sci-fi
# 2             action, adventure, sci-fi
# 3  action, drama, mystery, supernatural
# 4      adventure, fantasy, supernatural
#
#                                             synopsis   type  episodes  \
# 0  crime is timeless. by the year 2071, humanity ...     tv      26.0
# 1  another day, another bounty—such is the life o...  movie       1.0
# 2  vash the stampede is the man with a $$60,000,0...     tv      26.0
# 3  robin sena is a powerful craft user drafted in...     tv      26.0
# 4  it is the dark century and the people are suff...     tv      52.0
#
#    popularity  members         studios    source  favorites  \
# 0          43  1771505         sunrise  original      78525
# 1         602   360978           bones  original       1448
# 2         246   727252        madhouse     manga      15035
# 3        1795   111931         sunrise  original        613
# 4        5126    15001  toei animation     manga         14
#
#                  rating  year  \
# 0              rated 17  1998
# 1              rated 17  2001
# 2  parental guidance 13  1998
# 3  parental guidance 13  2002
# 4     parental guidance  2004
#
#                                        combined_text
# 0  action award winning scifi crime timeless year...
# 1  action scifi another day another bounty—such l...
# 2  action adventure scifi vash stampede man 60000...
# 3  action drama mystery supernatural robin sena p...
# 4  adventure fantasy supernatural dark century pe...

# %%
# Load saved files from collaborative based model
svd = joblib.load("data/svd_model_3.pkl")
user_clean = pd.read_csv("data/user_clean_processed_2.csv")

# %% [markdown]
# Now we will create a new virtual user with  3 new anime ratings.

# %%
# New user ratings
new_user_ratings = [
    {'user_id': 0, 'anime_id': 11111, 'rating': 8},   # Anime ID 1 with rating 8
    {'user_id': 0, 'anime_id': 5042, 'rating': 9},  # Anime ID 50 with rating 9
    {'user_id': 0, 'anime_id': 11617, 'rating': 9}, # Anime ID 200 with rating 7
]

# Convert to df and append to user_clean
new_user_df = pd.DataFrame(new_user_ratings)
updated_user_clean = pd.concat([user_clean, new_user_df], ignore_index=True)

# %% [markdown]
# Now we will create our hybrid recommendation functions by combining both content + collaborative data.

# %%
def get_recommendations_with_score_and_rank(anime_id, cosine_sim, df, top_n=10, popularity_threshold=10000):
    idx = df.index[df['anime_id'] == anime_id][0]
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    top_anime_indices = [i[0] for i in sim_scores[1:]]
    top_sim_scores = [i[1] for i in sim_scores[1:]]
    
    recommendations = df.iloc[top_anime_indices][['anime_id', 'name', 'genres', 'popularity', 'score', 'rank']].copy()
    recommendations['similarity_score'] = top_sim_scores
    
    recommendations = recommendations[recommendations['popularity'] <= popularity_threshold]
    
    recommendations['popularity_norm'] = 1 / (recommendations['popularity'] + 1)
    recommendations['rank_norm'] = 1 / (recommendations['rank'] + 1)
    recommendations['score_norm'] = recommendations['score'] / 10  # Assuming max score is 10
    
    recommendations['weighted_score'] = (
        0.9 * recommendations['similarity_score'] +
        0.1 * recommendations['popularity_norm'] +
        0 * recommendations['score_norm'] +
        0 * recommendations['rank_norm']
    )
    
    recommendations = recommendations.sort_values(by='weighted_score', ascending=False)
    
    return recommendations.head(top_n)

# %% [markdown]
# _(We have tuned the model weight to get the best results)_

# %%
def hybrid_recommendations_for_new_user(new_user_ratings, svd_model, cosine_sim, anime_df, top_n=10, cf_weight=0.6, content_weight=0.4):
    collaborative_scores = []
    all_anime_ids = anime_df['anime_id'].unique()

    for anime_id in all_anime_ids:
        try:
            pred = svd_model.predict(uid=0, iid=anime_id)
            collaborative_scores.append((anime_id, pred.est))
        except Exception:
            collaborative_scores.append((anime_id, 0))

    collaborative_df = pd.DataFrame(collaborative_scores, columns=['anime_id', 'cf_score'])

    watched_anime_ids = [rating['anime_id'] for rating in new_user_ratings]
    content_scores = []

    for anime_id in watched_anime_ids:
        print(f"Fetching recommendations for Anime ID: {anime_id}")
        try:
            similar_anime = get_recommendations_with_score_and_rank(anime_id, cosine_sim, anime_df, top_n=10)
            content_scores.append(similar_anime[['anime_id', 'weighted_score']])
        except Exception as e:
            print(f"Error processing Anime ID {anime_id}: {e}")

    if content_scores:
        content_scores = pd.concat(content_scores).groupby('anime_id', as_index=False).mean()
    else:
        print("No content-based recommendations found. Defaulting to collaborative filtering only.")
        content_scores = pd.DataFrame(columns=['anime_id', 'weighted_score'])

    hybrid_df = pd.merge(collaborative_df, content_scores, on='anime_id', how='outer').fillna(0)
    hybrid_df['hybrid_score'] = (cf_weight * hybrid_df['cf_score']) + (content_weight * hybrid_df['weighted_score'])
    hybrid_df = pd.merge(hybrid_df, anime_df[['anime_id', 'name', 'genres', 'year', 'studios', 'rank']], on='anime_id')
    hybrid_df = hybrid_df.sort_values(by='hybrid_score', ascending=False).head(top_n)

    return hybrid_df

# %%
# Generate hybrid recommendations for the new user
hybrid_recs_new_user = hybrid_recommendations_for_new_user(
    new_user_ratings=new_user_ratings,
    svd_model=svd,
    cosine_sim=cosine_sim,
    anime_df=anime_filtered_df,
    top_n=30,
    cf_weight=0.1,
    content_weight=0.9
)

hybrid_recs_new_user[['name', 'genres', 'year', 'studios', 'rank', 'hybrid_score']]
# Out:
# Fetching recommendations for Anime ID: 11111
# Fetching recommendations for Anime ID: 5042
# Fetching recommendations for Anime ID: 11617
#                                                    name  \
# 5074                                high school dxd new
# 7223                               high school dxd hero
# 5943                               high school dxd born
# 4804                                high school dxd ova
# 3736                                    kiss x sis (tv)
# 9237                                       chainsaw man
# 9150                                      godzilla: s.p
# 9455                                  lupin iii: part 6
# 9989        jijou wo shiranai tenkousei ga guigui kuru.
# 9368                                   do it yourself!!
# 9240                         isekai meikyuu de harem wo
# 9770  youkoso jitsuryoku shijou shugi no kyoushitsu ...
# 9669                                     skip to loafer
# 4970                                 suki tte ii na yo.
# 7583                                  lupin iii: part 5
# 9883                     pui pui molcar: driving school
# 4650                          another: the other - inga
# 9916                                  hirano to kagiura
# 8969                   boku no hero academia 5th season
# 4880                           high school dxd specials
# 7250                                             citrus
# 1796  inukami! the movie: tokumei reiteki sousakan k...
# 5433                                       youkai watch
# 1339                              gift: eternal rainbow
# 3109                   fullmetal alchemist: brotherhood
# 3989                                seitokai yakuindomo
# 2308                                              mokke
# 5170                                           love lab
# 813                                            inukami!
# 4113                                        steins;gate
#
#                                           genres  year  \
# 5074              action, comedy, romance, ecchi  2013
# 7223              action, comedy, romance, ecchi  2018
# 5943              action, comedy, romance, ecchi  2015
# 4804                      comedy, romance, ecchi  2012
# 3736                      comedy, romance, ecchi  2010
# 9237                             action, fantasy  2022
# 9150      action, award winning, mystery, sci-fi  2021
# 9455          action, adventure, comedy, mystery  2021
# 9989                                      comedy  2023
# 9368                               slice of life  2022
# 9240  action, adventure, fantasy, romance, ecchi  2022
# 9770                             drama, suspense  2022
# 9669                                       drama  2023
# 4970                              drama, romance  2012
# 7583          action, adventure, comedy, mystery  2018
# 9883                                      comedy  2022
# 4650                   horror, mystery, suspense  2012
# 9916                                   boys love  2023
# 8969                                      action  2021
# 4880                      comedy, romance, ecchi  2012
# 7250                  drama, girls love, romance  2018
# 1796        comedy, romance, supernatural, ecchi  2007
# 5433                        comedy, supernatural  2014
# 1339                      comedy, drama, romance  2006
# 3109           action, adventure, drama, fantasy  2009
# 3989                                      comedy  2010
# 2308        mystery, slice of life, supernatural  2007
# 5170                             comedy, romance  2013
# 813         comedy, romance, supernatural, ecchi  2006
# 4113                     drama, sci-fi, suspense  2011
#
#                            studios    rank  hybrid_score
# 5074                           tnk  1789.0      1.176087
# 7223                      passione  2783.0      1.141929
# 5943                           tnk  2016.0      1.102432
# 4804                           tnk  2700.0      1.080895
# 3736                         feel.  5761.0      1.074891
# 9237                         mappa    85.0      1.061099
# 9150                 bones, orange  5588.0      1.012803
# 9455             tms entertainment  3195.0      1.011367
# 9989               studio signpost  1812.0      1.008618
# 9368                      pine jam  1797.0      1.008171
# 9240                      passione  5979.0      1.006301
# 9770                        lerche   431.0      1.004621
# 9669                    p.a. works   291.0      1.003387
# 4970                         zexcs  2060.0      0.999995
# 7583        telecom animation film   429.0      0.999670
# 9883                    uchupeople  3439.0      0.998603
# 4650                    p.a. works  2688.0      0.998223
# 9916                   studio deen  5286.0      0.993024
# 8969                         bones  2121.0      0.973929
# 4880                           tnk  2702.0      0.944745
# 7250                      passione  6600.0      0.916173
# 1796                    seven arcs  3903.0      0.897988
# 5433                           olm  5999.0      0.892639
# 1339                           olm  5952.0      0.889229
# 3109                         bones     1.0      0.881736
# 3989                       gohands  1519.0      0.881587
# 2308  madhouse, tezuka productions  3764.0      0.881149
# 5170                     doga kobo  2488.0      0.876025
# 813                     seven arcs  2883.0      0.868468
# 4113                     white fox     3.0      0.867839

# %% [markdown]
# A prior run's result are also kept for comparison.

# %% [markdown]
# | Name                                  | Genres                                   | Year | Studios                 | Rank   | Hybrid Score |
# |---------------------------------------|------------------------------------------|------|-------------------------|--------|--------------|
# | High School DxD Hero                  | Action, Comedy, Romance, Ecchi           | 2018 | Passione                | 2783.0 | 1.850334     |
# | Chainsaw Man                          | Action, Fantasy                          | 2022 | MAPPA                   | 85.0   | 1.819940     |
# | High School DxD New                   | Action, Comedy, Romance, Ecchi           | 2013 | TNK                     | 1789.0 | 1.805281     |
# | Fullmetal Alchemist: Brotherhood      | Action, Adventure, Drama, Fantasy        | 2009 | Bones                   | 1.0    | 1.762574     |
# | Steins;Gate                           | Drama, Sci-Fi, Suspense                  | 2011 | White Fox               | 3.0    | 1.754490     |
# | Kimi no Na wa.                        | Award Winning, Drama, Supernatural       | 2016 | CoMix Wave Films        | 27.0   | 1.743024     |
# | Gintama°                              | Action, Comedy, Sci-Fi                   | 2015 | Bandai Namco Pictures   | 4.0    | 1.739494     |
# | Gintama Movie 2: Kanketsu-hen         | Action, Comedy, Sci-Fi                   | 2013 | Sunrise                 | 21.0   | 1.736633     |
# | Godzilla: S.P                         | Action, Award Winning, Mystery, Sci-Fi   | 2021 | Bones, Orange           | 5588.0 | 1.735556     |
# | Lupin III: Part 6                     | Action, Adventure, Comedy, Mystery       | 2021 | TMS Entertainment       | 3195.0 | 1.734280     |
# | Jijou wo Shiranai Tenkousei ga Guigui | Comedy                                  | 2023 | Studio Signpost         | 1812.0 | 1.731836     |
# | Do It Yourself!!                      | Slice of Life                            | 2022 | Pine Jam                | 1797.0 | 1.731438     |
# | Isekai Meikyuu de Harem wo            | Action, Adventure, Fantasy, Romance, Ecchi | 2022 | Passione                | 5979.0 | 1.729776     |
# | Hunter x Hunter (2011)                | Action, Adventure, Fantasy               | 2011 | Madhouse                | 10.0   | 1.728369     |
# | Youkoso Jitsuryoku Shijou Shugi no... | Drama, Suspense                          | 2022 | Lerche                  | 431.0  | 1.728283     |
# | Citrus                                | Drama, Girls Love, Romance               | 2018 | Passione                | 6600.0 | 1.728229     |
# | Skip to Loafer                        | Drama                                   | 2023 | P.A. Works              | 291.0  | 1.727186     |
# | Code Geass: Hangyaku no Lelouch R2    | Action, Award Winning, Drama, Sci-Fi     | 2008 | Sunrise                 | 20.0   | 1.724871     |
# | Lupin III: Part 5                     | Action, Adventure, Comedy, Mystery       | 2018 | Telecom Animation Film  | 429.0  | 1.723882     |
# | Gintama'                              | Action, Comedy, Sci-Fi                   | 2011 | Sunrise                 | 8.0    | 1.723712     |

# %% [markdown]
# It is evident that we have to diversify our recommendation so that it doesn't repeat the same series over and over again.

# %%
def diversify_recommendations_by_keyword(df, column='name', max_per_keyword=1):
    keyword_counts = {}
    diversified = []
    
    for _, row in df.iterrows():
        name = row[column]
        keywords = [word.lower() for word in name.split() if len(word) > 3]  
        
        if all(keyword_counts.get(keyword, 0) < max_per_keyword for keyword in keywords):
            diversified.append(row)
            for keyword in keywords:
                keyword_counts[keyword] = keyword_counts.get(keyword, 0) + 1

    return pd.DataFrame(diversified)

# %%
# Diversify recommendations by limiting repeating keywords
diversified_recs = diversify_recommendations_by_keyword(hybrid_recs_new_user, column='name', max_per_keyword=1)

diversified_recs[['anime_id', 'name', 'genres', 'hybrid_score']]
# Out:
#       anime_id                                               name  \
# 5074     15451                                high school dxd new
# 3736      7593                                    kiss x sis (tv)
# 9237     44511                                       chainsaw man
# 9150     43229                                      godzilla: s.p
# 9455     49040                                  lupin iii: part 6
# 9989     53621        jijou wo shiranai tenkousei ga guigui kuru.
# 9368     48542                                   do it yourself!!
# 9240     44524                         isekai meikyuu de harem wo
# 9770     51096  youkoso jitsuryoku shijou shugi no kyoushitsu ...
# 9669     50416                                     skip to loafer
# 4970     14289                                 suki tte ii na yo.
# 4650     11701                          another: the other - inga
# 9916     52364                                  hirano to kagiura
# 7250     34382                                             citrus
# 1796      2132  inukami! the movie: tokumei reiteki sousakan k...
# 5433     19157                                       youkai watch
# 1339      1581                              gift: eternal rainbow
# 3109      5114                   fullmetal alchemist: brotherhood
# 3989      8675                                seitokai yakuindomo
# 2308      2931                                              mokke
# 5170     16353                                           love lab
# 4113      9253                                        steins;gate
#
#                                           genres  hybrid_score
# 5074              action, comedy, romance, ecchi      1.176087
# 3736                      comedy, romance, ecchi      1.074891
# 9237                             action, fantasy      1.061099
# 9150      action, award winning, mystery, sci-fi      1.012803
# 9455          action, adventure, comedy, mystery      1.011367
# 9989                                      comedy      1.008618
# 9368                               slice of life      1.008171
# 9240  action, adventure, fantasy, romance, ecchi      1.006301
# 9770                             drama, suspense      1.004621
# 9669                                       drama      1.003387
# 4970                              drama, romance      0.999995
# 4650                   horror, mystery, suspense      0.998223
# 9916                                   boys love      0.993024
# 7250                  drama, girls love, romance      0.916173
# 1796        comedy, romance, supernatural, ecchi      0.897988
# 5433                        comedy, supernatural      0.892639
# 1339                      comedy, drama, romance      0.889229
# 3109           action, adventure, drama, fantasy      0.881736
# 3989                                      comedy      0.881587
# 2308        mystery, slice of life, supernatural      0.881149
# 5170                             comedy, romance      0.876025
# 4113                     drama, sci-fi, suspense      0.867839

# %% [markdown]
# Our keyword limit based diversification works really great and we can keep this model as it is now.

# %% [markdown]
# We also tried a series keyword diversification but it doesn't work as intended many times.

# %%
def diversify_recommendations_by_series_keyword(df, column='name', keywords=None, max_per_keyword=1):
    
    keyword_counts = {}
    diversified = []

    for _, row in df.iterrows():
        name = row[column].lower()
        keyword_found = None

        if keywords:
            for keyword in keywords:
                if keyword.lower() in name:
                    keyword_found = keyword.lower()
                    break

        if not keyword_found:
            diversified.append(row)
        else:
            if keyword_counts.get(keyword_found, 0) < max_per_keyword:
                diversified.append(row)
                keyword_counts[keyword_found] = keyword_counts.get(keyword_found, 0) + 1

    return pd.DataFrame(diversified)

# %% [markdown]
# We also made a keyword extractor function to find all series keywords easily.

# %%
import pandas as pd
from collections import Counter

anime_titles = anime_filtered_df['name']

keywords = []
for title in anime_titles:
    keywords.extend(title.lower().split())

keyword_counts = Counter(keywords)

series_keywords = [keyword for keyword, count in keyword_counts.items() if count > 3]

print("Extracted Series Keywords:", series_keywords)
# Out:
# Extracted Series Keywords: ['cowboy', 'no', 'tobira', 'witch', 'hunter', 'bouken', 'ou', '21', 'hachimitsu', 'to', 'clover', 'heart:', 'wild', 'initial', 'd', 'stage', 'monster', 'naruto', 'tennis', 'ouji-sama', 'ring', 'ni', 'kakero', '1', 'school', 'rumble', 'trinity', 'blood', 'neon', 'genesis', 'evangelion', 'evangelion:', 'death', '&', 'rebirth', 'the', 'end', 'of', 'berserk', 'koukaku', 'kidoutai', 'rurouni', 'kenshin:', 'meiji', 'kenkaku', 'romantan', '-', 'e', 'aa!', 'megami-sama!', '(tv)', 'tenshi', 'kidou', 'ai', 'yori', 'appleseed', '(movie)', 'blue', 'da', 'capo', 'rozen', 'animation', 'chou', 'black', 'cat', 'full', 'metal', 'panic!', 'second', 'raid', 'gakuen', 'alice', 'soukyuu', 'fafner:', 'dead', 'aggressor', 'mahou', 'shoujo', 'lyrical', 'nanoha', 'shuffle!', 'senshi', 'gundam', 'gundam:', 'dai', 'ms', 'shoutai', 'naka', 'sensou', 'report', '0083:', 'stardust', 'memory', 'gyakushuu', 'victory', 'shin', 'senki', 'wing:', 'endless', 'x', 'seed', 'destiny', 'turn', 'a', 'g', 'last', 'mai-otome', 'densetsu', 'air', 'akazukin', 'ayashi', 'boys', 'hana', 'dorobou', 'jing', 'in', 'heaven', 'bakuretsu', 'ichiban!', 'henshin', 'uchuu', 'koukou', 'el', 'alternative', 'world', '2:', 'final', 'fruits', 'basket', 'fullmetal', 'moon', 'wo', 'fushigi', 'yuugi', 'gate', 'saiyuuki', 'green', 'gunslinger', 'girl', 'hikaru', 'go', 'hunter:', 'original', 'video', 'island', 'kaitou', 'miko', 'kanon', 'kanojo', 'jijou', 'kono', 'mo', 'sekai', 'kimi', 'ga', 'eien', 'kita', 'diamond', 'cutey', 'honey', 'rei', 'juuni', 'shaman', 'king', 'sensei', 'negima!', 'maria-sama', 'miteru', 'iru', 'boku', 'peace', 'maker', 'kurogane', 'ten', 'stone', 'hime', 'samurai', '7', 'princess', 'slam', 'dawn', 'tokyo', 'triangle', 'sweet', 'forever', 'tsubasa', 'chronicle', 'ultra', 'ova', 'tenkuu', 'first', 'third', 'love', 'hina', 'christmas', 'special:', 'silent', 'eve', 'haru', 'sakura', 'macross', 'zero', 'sen', 'na', 'rain', 'senki:', 'eiyuu', 'kishi', 'den', 'or', 'die', 'tv', 'ranma', 'project', 'a-ko', '2', 'koi', 'monogatari', 'senkan', 'prince', 'darkness', 'dragon', 'ball', 'jigoku', 'master', 'cardcaptor', 'dan', 'koukyoushihen', 'eureka', 'seven', 'honoo', 'genshiken', 'girls', 'season', 'meitantei', 'great', 'adventure', 'harukanaru', 'toki', 'de:', 'hachiyou', 'shou', 'ichigo', '100%', 'inuyasha', 'konjiki', 'gash', 'kyou', 'kara', 'jungle', 'wa', 'itsumo', 'hare', 'nochi', 'hoshi', 'koe', 'uta', 'happy☆lesson', 'advance', 'hajime', 'ippo:', 'road', 'vs.', 'arata', 'naru', 'golden', 'boy', 'bleach', 'mahoutsukai', 'taisetsu', 'koto', 'kiddy', 'motto', 'mono', 'joe', 'angel', 'heart', 'anne', 'area', 'bakuten', 'shoot', 'beyblade', 'comic', 'party', 'seikai', 'di', 'gi', 'charat', 'drive', 'eyes', 'cinderella', 'mirai', 'shounen', 'conan', 'movie', 'ikka', 'zettai', 'chiisana', 'ace', 'nerae!', '(1979)', 'xiao', 'qian', 'fantasy', 'vii:', 'children', 'hand', 'maid', 'happy', 'sakusen', 'paradise', 'kiss', 'mousou', 'keisatsu', 'on', 'peach', 'piano', 'midori', 'hibi', 'mahoujin', 'guruguru', 'mama', '4', 'mokushiroku', 'ryuu', 'gaiden:', 'suiri', 'kizuna', 'w:', 'twilight', 'yousei', 'magical', 'ojamajo', 'doremi', 'shakugan', 'shana', 'fate/stay', 'night', 'ufo', 'natsu', 'memories', 'off', '2nd', 'aika', 'warawanai', 'burn', 'up', 'sareta', 'card', 'bannou', 'bunka', 'neko-musume', 'dash!', 'wa,', 'shite', 'sono', 'ka?', 'bu', 'futari', 'galaxy', 'tales', 'ii', 'iii', 'special', 'seihou', 'star', 'otogi', 'ankoku', 'hakaishin', 'blood:', 'vampire', 'tantei', 'q', 'order', 'gun', 'sword', 'kore', 'watashi', 'hametsu', 'mars', 'tonari', 'yamada-kun', 'kurenai', 'buta', '½:', 'stratos', 'dirty', 'pair', 'seitokai', 'kaleido', 'aratanaru', 'extra', 'legend', 'alchemist:', 'shiro', 'kumo', 'yakusoku', 'basho', 'magic', 'knight', 'rayearth', 'perfect', 'phantom', 'kakumei', '1:', 'yuki', 'dattebayo!', 'himitsu', 'weiß', 'ultimate', 'fight', '4:', 'guren', 'kagami', '3:', 'ken', 'omoi', 'mushishi', 'one', 'piece', '02:', 'daibouken', '03:', ' ...

# %%
# Diversify recommendations based on series keywords
diversified_recs = diversify_recommendations_by_series_keyword(
    df=hybrid_recs_new_user,
    column='name',
    keywords=series_keywords,
    max_per_keyword=2 
)

diversified_recs[['anime_id', 'name', 'genres', 'hybrid_score']]
# Out:
#       anime_id                                               name  \
# 5074     15451                                high school dxd new
# 7223     34281                               high school dxd hero
# 3736      7593                                    kiss x sis (tv)
# 9237     44511                                       chainsaw man
# 9455     49040                                  lupin iii: part 6
# 9989     53621        jijou wo shiranai tenkousei ga guigui kuru.
# 9368     48542                                   do it yourself!!
# 9770     51096  youkoso jitsuryoku shijou shugi no kyoushitsu ...
# 9669     50416                                     skip to loafer
# 4970     14289                                 suki tte ii na yo.
# 7583     35857                                  lupin iii: part 5
# 4650     11701                          another: the other - inga
# 7250     34382                                             citrus
# 1339      1581                              gift: eternal rainbow
# 3989      8675                                seitokai yakuindomo
#
#                                   genres  hybrid_score
# 5074      action, comedy, romance, ecchi      1.176087
# 7223      action, comedy, romance, ecchi      1.141929
# 3736              comedy, romance, ecchi      1.074891
# 9237                     action, fantasy      1.061099
# 9455  action, adventure, comedy, mystery      1.011367
# 9989                              comedy      1.008618
# 9368                       slice of life      1.008171
# 9770                     drama, suspense      1.004621
# 9669                               drama      1.003387
# 4970                      drama, romance      0.999995
# 7583  action, adventure, comedy, mystery      0.999670
# 4650           horror, mystery, suspense      0.998223
# 7250          drama, girls love, romance      0.916173
# 1339              comedy, drama, romance      0.889229
# 3989                              comedy      0.881587

# %% [markdown]
# The result from this approach is questionable, thus we can stay with our first diversification method.
